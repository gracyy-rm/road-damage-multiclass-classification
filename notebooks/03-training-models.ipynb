# %% [markdown]
# # Road Damage Multi-Class Classification: Model Training
#
# Train and compare the following architectures:
#
# - ResNet18
# - MobileNetV3-Small
# - EfficientNet-B0
#
# Training will be executed through the command line using `main.py`.

# %%
# !rm -rf /kaggle/working/road-damage-multiclass-classification

# %%
cd ~
# Out:
# /root

# %%
import os
os.chdir("/kaggle/working/")

# %%
pwd
# Out:
# '/kaggle/working'

# %%
# git clone 
# !git clone "https://github.com/gracyy-rm/road-damage-multiclass-classification".git
# Out:
# Cloning into 'road-damage-multiclass-classification'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 69 (delta 34), reused 56 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 8.42 MiB | 33.40 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
cd road-damage-multiclass-classification
# Out:
# /kaggle/working/road-damage-multiclass-classification

# %%
# %cd /kaggle/working/road-damage-multiclass-classification
# Out:
# /kaggle/working/road-damage-multiclass-classification

# %%
! pip install torchinfo tensorboard -q

# %% [markdown]
# ## Configuration

# %%
import json
config_path = "config/config.json"
with open(config_path,"r") as file:
    config = json.load(file)
config
# Out:
# {'paths': {'train_csv': '',
#   'val_csv': '',
#   'test_csv': '',
#   'experiments_dir': 'experiments/'},
#  'model': {'architecture': 'resnet18',
#   'pretrained': True,
#   'num_classes': 5,
#   'freeze_backbone': 'partial'},
#  'classes': {'mapping': {'0': 'Major Damage',
#    '1': 'Manhole',
#    '2': 'Minor Damage',
#    '3': 'Normal Road',
#    '4': 'Speed Breaker'}},
#  'training_parameters': {'batch_size': 32,
#   'learning_rate': 0.001,
#   'epochs': 25,
#   'image_size': 224,
#   'seed': 1,
#   'accumulation_steps': 2,
#   'early_stopping_patience': 8,
#   'weight_decay': 0.01},
#  'hardware': {'num_workers': 4}}

# %% [markdown]
# ## Train EfficientNet_B0

# %%
config['model']['architecture'] = "efficientnet_b0"
config['paths']['train_csv'] ="/kaggle/input/datasets/gracyyadav79/dataset-csvs/train.csv"
config['paths']['val_csv'] = "/kaggle/input/datasets/gracyyadav79/dataset-csvs/val.csv"
config['paths']['test_csv'] = "/kaggle/input/datasets/gracyyadav79/dataset-csvs/test.csv"
with open(config_path, 'w') as file:
    json.dump(config, file, indent=4)

# %%
config
# Out:
# {'paths': {'train_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/train.csv',
#   'val_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/val.csv',
#   'test_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/test.csv',
#   'experiments_dir': 'experiments/'},
#  'model': {'architecture': 'efficientnet_b0',
#   'pretrained': True,
#   'num_classes': 5,
#   'freeze_backbone': 'partial'},
#  'classes': {'mapping': {'0': 'Major Damage',
#    '1': 'Manhole',
#    '2': 'Minor Damage',
#    '3': 'Normal Road',
#    '4': 'Speed Breaker'}},
#  'training_parameters': {'batch_size': 32,
#   'learning_rate': 0.001,
#   'epochs': 25,
#   'image_size': 224,
#   'seed': 1,
#   'accumulation_steps': 2,
#   'early_stopping_patience': 8,
#   'weight_decay': 0.05},
#  'hardware': {'num_workers': 4}}

# %%
# !python main.py --config ./config/config.json
# Out:
# Running on: cuda
# Training samples: 4,443
# Validation samples: 950
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|███████████████████████████████████████| 20.5M/20.5M [00:00<00:00, 231MB/s]
#
# --- MODEL SUMMARY ---
#
# ...
# Layer (type:depth-idx)                                       Output Shape              Param #
# ...
# RoadDamageClassifier                                         [32, 5]                   --
# ├─EfficientNet: 1-1                                          [32, 1280]                --
# │    └─Sequential: 2-1                                       [32, 1280, 7, 7]          --
# │    │    └─Conv2dNormActivation: 3-1                        [32, 32, 112, 112]        (928)
# │    │    └─Sequential: 3-2                                  [32, 16, 112, 112]        (1,448)
# ...

# %%
config['model']['freeze_backbone'] = False
with open(config_path, 'w') as file:
    json.dump(config, file, indent=4)

config
# Out:
# {'paths': {'train_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/train.csv',
#   'val_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/val.csv',
#   'test_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/test.csv',
#   'experiments_dir': 'experiments/'},
#  'model': {'architecture': 'efficientnet_b0',
#   'pretrained': True,
#   'num_classes': 5,
#   'freeze_backbone': False},
#  'classes': {'mapping': {'0': 'Major Damage',
#    '1': 'Manhole',
#    '2': 'Minor Damage',
#    '3': 'Normal Road',
#    '4': 'Speed Breaker'}},
#  'training_parameters': {'batch_size': 32,
#   'learning_rate': 0.001,
#   'epochs': 25,
#   'image_size': 224,
#   'seed': 1,
#   'accumulation_steps': 2,
#   'early_stopping_patience': 8,
#   'weight_decay': 0.05},
#  'hardware': {'num_workers': 4},
#  'model_name': 'resnet18'}

# %%
# !python main.py --config ./config/config.json
# Out:
# Running on: cuda
# Training samples: 4,443
# Validation samples: 950
#
# --- MODEL SUMMARY ---
#
# ...
# Layer (type:depth-idx)                                       Output Shape              Param #
# ...
# RoadDamageClassifier                                         [32, 5]                   --
# ├─EfficientNet: 1-1                                          [32, 1280]                --
# │    └─Sequential: 2-1                                       [32, 1280, 7, 7]          --
# │    │    └─Conv2dNormActivation: 3-1                        [32, 32, 112, 112]        928
# │    │    └─Sequential: 3-2                                  [32, 16, 112, 112]        1,448
# │    │    └─Sequential: 3-3                                  [32, 24, 56, 56]          16,714
# │    │    └─Sequential: 3-4                                  [32, 40, 28, 28]          46,640
# │    │    └─Sequential: 3-5                                  [32, 80, 14, 14]          242,930
# ...

# %%
os.chdir("/kaggle/working/")

# %% [markdown]
# ## Train RESNET18

# %%
config['model']['architecture'] = "resnet18"
with open(config_path, 'w') as file:
    json.dump(config, file, indent=4)
config
# Out:
# {'paths': {'train_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/train.csv',
#   'val_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/val.csv',
#   'test_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/test.csv',
#   'experiments_dir': 'experiments/'},
#  'model': {'architecture': 'resnet18',
#   'pretrained': True,
#   'num_classes': 5,
#   'freeze_backbone': False},
#  'classes': {'mapping': {'0': 'Major Damage',
#    '1': 'Manhole',
#    '2': 'Minor Damage',
#    '3': 'Normal Road',
#    '4': 'Speed Breaker'}},
#  'training_parameters': {'batch_size': 32,
#   'learning_rate': 0.001,
#   'epochs': 25,
#   'image_size': 224,
#   'seed': 1,
#   'accumulation_steps': 2,
#   'early_stopping_patience': 8,
#   'weight_decay': 0.05},
#  'hardware': {'num_workers': 4},
#  'model_name': 'resnet18'}

# %%
# !python main.py --config ./config/config.json
# Out:
# Running on: cuda
# Training samples: 4,443
# Validation samples: 950
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|███████████████████████████████████████| 44.7M/44.7M [00:00<00:00, 163MB/s]
#
# --- MODEL SUMMARY ---
#
# ...
# Layer (type:depth-idx)                        Output Shape              Param #
# ...
# RoadDamageClassifier                          [32, 5]                   --
# ├─ResNet: 1-1                                 [32, 512]                 --
# │    └─Conv2d: 2-1                            [32, 64, 112, 112]        9,408
# │    └─BatchNorm2d: 2-2                       [32, 64, 112, 112]        128
# │    └─ReLU: 2-3                              [32, 64, 112, 112]        --
# │    └─MaxPool2d: 2-4                         [32, 64, 56, 56]          --
# │    └─Sequential: 2-5                        [32, 64, 56, 56]          --
# ...

# %% [markdown]
# ## Train MobileNet_V3_Small

# %%
os.chdir("/kaggle/working/road-damage-multiclass-classification")

# %%
config['model']['architecture'] = "mobilenet_v3_small"
with open(config_path, 'w') as file:
    json.dump(config, file, indent=4)
config
# Out:
# {'paths': {'train_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/train.csv',
#   'val_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/val.csv',
#   'test_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/test.csv',
#   'experiments_dir': 'experiments/'},
#  'model': {'architecture': 'mobilenet_v3_small',
#   'pretrained': True,
#   'num_classes': 5,
#   'freeze_backbone': False},
#  'classes': {'mapping': {'0': 'Major Damage',
#    '1': 'Manhole',
#    '2': 'Minor Damage',
#    '3': 'Normal Road',
#    '4': 'Speed Breaker'}},
#  'training_parameters': {'batch_size': 32,
#   'learning_rate': 0.001,
#   'epochs': 25,
#   'image_size': 224,
#   'seed': 1,
#   'accumulation_steps': 2,
#   'early_stopping_patience': 8,
#   'weight_decay': 0.05},
#  'hardware': {'num_workers': 4},
#  'model_name': 'resnet18'}

# %%
# !python main.py --config ./config/config.json
# Out:
# Running on: cuda
# Training samples: 4,443
# Validation samples: 950
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# 100%|██████████████████████████████████████| 9.83M/9.83M [00:00<00:00, 76.6MB/s]
#
# --- MODEL SUMMARY ---
#
# ...
# Layer (type:depth-idx)                                  Output Shape              Param #
# ...
# RoadDamageClassifier                                    [32, 5]                   --
# ├─MobileNetV3: 1-1                                      [32, 576]                 --
# │    └─Sequential: 2-1                                  [32, 576, 7, 7]           --
# │    │    └─Conv2dNormActivation: 3-1                   [32, 16, 112, 112]        464
# │    │    └─InvertedResidual: 3-2                       [32, 16, 56, 56]          744
# │    │    └─InvertedResidual: 3-3                       [32, 24, 28, 28]          3,864
# ...

# %%
import shutil
source_dir = "/kaggle/working/road-damage-multiclass-classification/experiments/"
output_filename = "/kaggle/working/my_experiments"

shutil.make_archive(output_filename, "zip", source_dir)
# Out:
# '/kaggle/working/my_experiments.zip'

# %%
config['model']['architecture'] = "efficientnet_b0"
with open(config_path, 'w') as file:
    json.dump(config, file, indent=4)
config
# Out:
# {'paths': {'train_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/train.csv',
#   'val_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/val.csv',
#   'test_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/test.csv',
#   'experiments_dir': 'experiments/'},
#  'model': {'architecture': 'efficientnet_b0',
#   'pretrained': True,
#   'num_classes': 5,
#   'freeze_backbone': 'partial'},
#  'classes': {'mapping': {'0': 'Major Damage',
#    '1': 'Manhole',
#    '2': 'Minor Damage',
#    '3': 'Normal Road',
#    '4': 'Speed Breaker'}},
#  'training_parameters': {'batch_size': 32,
#   'learning_rate': 0.001,
#   'epochs': 25,
#   'image_size': 224,
#   'seed': 1,
#   'accumulation_steps': 2,
#   'early_stopping_patience': 8,
#   'weight_decay': 0.05},
#  'hardware': {'num_workers': 4}}

# %%
# !python main.py --config ./config/config.json
# Out:
# Running on: cuda
# Training samples: 4,443
# Validation samples: 950
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|███████████████████████████████████████| 20.5M/20.5M [00:00<00:00, 136MB/s]
#
# --- MODEL SUMMARY ---
#
# ...
# Layer (type:depth-idx)                                       Output Shape              Param #
# ...
# RoadDamageClassifier                                         [32, 5]                   --
# ├─EfficientNet: 1-1                                          [32, 1280]                --
# │    └─Sequential: 2-1                                       [32, 1280, 7, 7]          --
# │    │    └─Conv2dNormActivation: 3-1                        [32, 32, 112, 112]        (928)
# │    │    └─Sequential: 3-2                                  [32, 16, 112, 112]        (1,448)
# ...

# %%
import shutil
source_dir = "/kaggle/working/road-damage-multiclass-classification/experiments/"
output_filename = "/kaggle/working/efficientnet_no_overfit"

shutil.make_archive(output_filename, "zip", source_dir)
# Out:
# '/kaggle/working/efficientnet_no_overfit.zip'

# %% [markdown]
# ## Train EfficientNet_B0 with Focal loss

# %%
config['model']['architecture'] = "efficientnet_b0"
config['model']['freeze_backbone'] = False
with open(config_path, 'w') as file:
    json.dump(config, file, indent=4)
config
# Out:
# {'paths': {'train_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/train.csv',
#   'val_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/val.csv',
#   'test_csv': '/kaggle/input/datasets/gracyyadav79/dataset-csvs/test.csv',
#   'experiments_dir': 'experiments/'},
#  'model': {'architecture': 'efficientnet_b0',
#   'pretrained': True,
#   'num_classes': 5,
#   'freeze_backbone': False},
#  'classes': {'mapping': {'0': 'Major Damage',
#    '1': 'Manhole',
#    '2': 'Minor Damage',
#    '3': 'Normal Road',
#    '4': 'Speed Breaker'}},
#  'training_parameters': {'batch_size': 32,
#   'learning_rate': 0.001,
#   'epochs': 25,
#   'image_size': 224,
#   'seed': 1,
#   'accumulation_steps': 2,
#   'early_stopping_patience': 8,
#   'weight_decay': 0.01},
#  'hardware': {'num_workers': 4}}

# %%
# !python main.py --config ./config/config.json
# Out:
# Running on: cuda
# Training samples: 4,443
# Validation samples: 950
#
# --- MODEL SUMMARY ---
#
# ...
# Layer (type:depth-idx)                                       Output Shape              Param #
# ...
# RoadDamageClassifier                                         [32, 5]                   --
# ├─EfficientNet: 1-1                                          [32, 1280]                --
# │    └─Sequential: 2-1                                       [32, 1280, 7, 7]          --
# │    │    └─Conv2dNormActivation: 3-1                        [32, 32, 112, 112]        928
# │    │    └─Sequential: 3-2                                  [32, 16, 112, 112]        1,448
# │    │    └─Sequential: 3-3                                  [32, 24, 56, 56]          16,714
# │    │    └─Sequential: 3-4                                  [32, 40, 28, 28]          46,640
# │    │    └─Sequential: 3-5                                  [32, 80, 14, 14]          242,930
# ...

# %%
import shutil
source_dir = "/kaggle/working/road-damage-multiclass-classification/experiments/efficientnet_b0_lr0.001_bs32_20260818_150942"
output_filename = "/kaggle/working/efficientnet_93.1"
shutil.make_archive(output_filename, "zip", source_dir)
# Out:
# '/kaggle/working/efficientnet_93.1.zip'
